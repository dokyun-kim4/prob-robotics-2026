# %%
P = {
    "metal": {
        "C": 100/428, 
        "L|C": {
            "metal": 0.8, 
            "plastic": 0, 
            "organics": 0, 
            "composite": 0, 
            "toxic": 0
        }
    },
    "plastic": {
        "C": 230/428, 
        "L|C": {
            "metal": 0, 
            "plastic": 0.9, 
            "organics": 0, 
            "composite": 0, 
            "toxic": 0
        }
    },
    "organics": {
        "C": 73/428, 
        "L|C": {
            "metal": 0, 
            "plastic": 0, 
            "organics": 0.6, 
            "composite": 0, 
            "toxic": 0
        }
    },
    "composite": {
        "C": 20/428, 
        "L|C": {
            "metal": 0.2, 
            "plastic": 0.05, 
            "organics": 0, 
            "composite": 1.0, 
            "toxic": 0
        }
    },
    "toxic": {
        "C": 5/428, 
        "L|C": {
            "metal": 0, 
            "plastic": 0.05, 
            "organics": 0.4, 
            "composite": 0, 
            "toxic": 1.0
        }
    }
}

# %%
def get_normalizer(label: str) -> float:
    classes = P.keys()
    normalizer = 0
    for category in classes:
        
        normalizer += P[label]["L|C"][category] * P[category]["C"]
    return normalizer

def C_given_L(category: str, label: str) -> float:
    numerator = P[label]["L|C"][category] * P[category]["C"]
    denominator = get_normalizer(label)
    return numerator/denominator

# %%
get_normalizer("metal")
# Out:
# 0.19626168224299068

# %%
classes = P.keys()
for category in classes:
    for label in classes:
        print(f"P({category}|{label}) = {C_given_L(category, label):.4}")
# Out:
# P(metal|metal) = 0.9524
# P(metal|plastic) = 0.0
# P(metal|organics) = 0.0
# P(metal|composite) = 0.0
# P(metal|toxic) = 0.0
# P(plastic|metal) = 0.0
# P(plastic|plastic) = 0.994
# P(plastic|organics) = 0.0
# P(plastic|composite) = 0.0
# P(plastic|toxic) = 0.0
# P(organics|metal) = 0.0
# P(organics|plastic) = 0.0
# P(organics|organics) = 0.9563
# P(organics|composite) = 0.0
# P(organics|toxic) = 0.0
# P(composite|metal) = 0.04762
# P(composite|plastic) = 0.004802
# P(composite|organics) = 0.0
# P(composite|composite) = 1.0
# P(composite|toxic) = 0.0
# P(toxic|metal) = 0.0
# P(toxic|plastic) = 0.0012
# P(toxic|organics) = 0.04367
# P(toxic|composite) = 0.0
# P(toxic|toxic) = 1.0
